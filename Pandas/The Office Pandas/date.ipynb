# %%
import pandas as pd
office= pd.read_csv('office.csv')
office['Dob'] = ['11/12/1990', '12/12/1990', '13/11/1990', '14/12/1990', '15/12/1990', '16/12/1990', '17/12/1990', '18/12/1990', '19/12/1990', '20/12/1990', '21/12/1990', '22/12/1990']
office["Dob"] = pd.to_datetime(office["Dob"], format='%d/%m/%Y')
monthcount= office['Dob'].groupby(office['Dob'].dt.month).count()
monthcount
# Out:
# Dob
# 11     1
# 12    11
# Name: Dob, dtype: int64

# %%
import pandas as pd
import numpy as np
sal = np.array(office['Salary'])
sal
office['Bonus'] = office['Salary']*0.1
office
# Out:
#               Name  Age          City  Salary  \
# 0    Micheal Scott   45      Scranton   65000
# 1     Jim Harlpert   32        Austin   45000
# 2       Pam Beesly   30      New York   30000
# 3   Dwight Schrute   35        Berlin   50000
# 4     Kelly Kapoor   28         Delhi   40000
# 5     Kevin Malone   48  Philadelphia   38000
# 6   Oscar Martinez   46   Mexico City   48000
# 7      Rayn Howard   25      New York   20000
# 8    Creed Bratton   68        Dallas   28000
# 9    Phyllis Vance   43      Scranton   32000
# 10   Angela Martin   30    Pittsburgh   35000
# 11  Stanley Hudson   55           NaN   50000
#
#                            Department        Dob   Bonus
# 0                             Manager 1990-12-11  6500.0
# 1                               Sales 1990-12-12  4500.0
# 2                        Receptionist 1990-11-13  3000.0
# 3   Assistent To The Regional Manager 1990-12-14  5000.0
# 4                    Customer Service 1990-12-15  4000.0
# ...
